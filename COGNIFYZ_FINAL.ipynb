# %% [markdown]
# ### Project Name
# ### Investment Behavior and Preferences Analysis

# %% [markdown]
# ### Problem Statement:
# ***This project focuses on analyzing how individuals make their investment decisions based on factors like age, gender, and savings objectives. By examining preferences for various financial instruments such as Mutual Funds, Equity Markets, Fixed Deposits, and others, the goal is to identify patterns and trends. Through this, I aim to understand what drives people to choose certain investment avenues and how their choices are influenced by different factors like returns, security, or duration***.

# %% [markdown]
# ### Motivation:
# ***In today’s world, making informed financial decisions is more important than ever. This project is motivated by my interest in understanding how different groups of people invest their money and what motivates those decisions. By analyzing the data, I hope to provide insights that can be useful for individuals to make better financial choices and for financial institutions to understand their customers better. Understanding these trends can also help improve financial education and lead to better-tailored investment options***.

# %% [markdown]
# Import necessary libraries

# %%
# NumPy: For handling large arrays and performing efficient mathematical operations
import numpy as np

# Pandas: For data manipulation and analysis using data structures like DataFrames
import pandas as pd

# Matplotlib: For creating static, animated, and interactive visualizations
import matplotlib.pyplot as plt

# Seaborn: For making statistical graphics with better visual appeal, built on top of Matplotlib
import seaborn as sns
#import warning for avoid warnings to be shown in the notebook
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# TASK 1:
# Objective:Understand the dataset structure.
# STEPS: 1) Load the dataset:import the dataset into a data analysis tool such as python .
#        2) Descriptive Statistics:Use descriptive function to gather information about the              number of entries,columns,and data types.

# %% [markdown]
# # Task 1: Data Overview
# ***Objective: Understand the dataset structure.*** <br>
# ***teps:*** <br>
# ***1.Load the dataset:*** Import the dataset into a data analysis tool such as python with pandas or spredsheet software.<br>
# ***2.Descriptive Statistics:*** Use descriptive functions(e.g info() in pamdas) to gather information about the number of entries,columns,and data types.

# %% [markdown]
# Load Data set

# %%
dataset = pd.read_csv("Data_set 2 - Copy.csv")
dataset
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
# check the structure of dataset
dataset.shape
# Out:
# (40, 24)

# %% [markdown]
# Display the structure of the dataset
#
#
#
#
# View the first few records

# %%
dataset.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %% [markdown]
# This will show data types, non-null counts, and memory usage

# %%
dataset.info() #This will show data types, non-null counts, and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
# check missing values
dataset.isnull().sum()
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %% [markdown]
# EDA
#
#
#
#
# Understanding Data Types and Descriptive Statistics

# %%
#Check Data Types
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
#Summary Statistics:
dataset.describe(include='all')
# Out:
#        gender        age Investment_Avenues  Mutual_Funds  Equity_Market  \
# count      40  40.000000                 40     40.000000      40.000000
# unique      2        NaN                  2           NaN            NaN
# top      Male        NaN                Yes           NaN            NaN
# freq       25        NaN                 37           NaN            NaN
# mean      NaN  27.800000                NaN      2.550000       3.475000
# std       NaN   3.560467                NaN      1.197219       1.131994
# min       NaN  21.000000                NaN      1.000000       1.000000
# 25%       NaN  25.750000                NaN      2.000000       3.000000
# 50%       NaN  27.000000                NaN      2.000000       4.000000
# 75%       NaN  30.000000                NaN      3.000000       4.000000
# max       NaN  35.000000                NaN      7.000000       6.000000
#
#         Debentures  Government_Bonds  Fixed_Deposits        PPF       Gold  \
# ...

# %%
dataset.describe()
print(dataset.describe().round(2))
# Out:
#          age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.00         40.00          40.00       40.00             40.00
# mean   27.80          2.55           3.48        5.75              4.65
# std     3.56          1.20           1.13        1.68              1.37
# min    21.00          1.00           1.00        1.00              1.00
# 25%    25.75          2.00           3.00        5.00              4.00
# 50%    27.00          2.00           4.00        6.50              5.00
# 75%    30.00          3.00           4.00        7.00              5.00
# max    35.00          7.00           6.00        7.00              7.00
#
#        Fixed_Deposits    PPF   Gold
# count           40.00  40.00  40.00
# mean             3.58   2.02   5.98
# std              1.80   1.61   1.14
# min              1.00   1.00   2.00
# 25%              2.75   1.00   6.00
# 50%              3.50   1.00   6.00
# 75%              5.00   2.25   7.00
# ...

# %% [markdown]
# # Task 2 : Gender Distribution<br>
# ***Objective:Visualize gender distribution in the dataset***<br>
# ***Steps:*** <br>
# ***1.Extract Gender Information:*** Identify and extract the gender column from the dataset<br>
# ***2.Visualization:*** Create a simple visualization,such as a bar chart or pie chart , to represent the distribution of gender in the dataset.<br>

# %%
# Extracting the Gender column
gender_column = dataset['gender'].value_counts()
gender_column
# Out:
# gender
# Male      25
# Female    15
# Name: count, dtype: int64

# %%
# Extracting the Gender column and calculating the counts for each category
gender_counts = dataset['gender'].value_counts()

# Creating the bar chart
plt.figure(figsize=(6,4))
gender_counts.plot(kind='bar', color=['skyblue', 'lightcoral'])

# Adding titles and labels
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')

# Displaying the bar chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Step 1: Calculate the total number of individuals and percentages
gender_counts = dataset['gender'].value_counts()
total_individuals = gender_counts.sum()

# Calculate the percentage of males and females
male_percentage = (gender_counts['Male'] / total_individuals) * 100
female_percentage = (gender_counts['Female'] / total_individuals) * 100

# Step 2: Create a bar chart showing male and female distribution with percentages
plt.figure(figsize=(6, 4))
plt.bar(gender_counts.index, gender_counts, color=['skyblue', 'lightcoral'])

# Annotating the bar chart with percentages
for i, count in enumerate(gender_counts):
    percentage = (count / total_individuals) * 100
    plt.text(i, count + 0.5, f'{percentage:.1f}%', ha='center', fontsize=12)

# Adding titles and labels
plt.title('Gender Distribution with Percentages')
plt.xlabel('Gender')
plt.ylabel('Count')

# Display the bar chart
plt.show()

# %% [markdown]
# ## Insight:
# ***In this dataset, males make up 62.5% of the total sample, which shows that there are more male investors compared to females. This suggests that, at least in this case, males seem more involved or are participating more in financial activities. However, it could also point to a potential gap in female participation, which could be due to factors like access to financial resources, confidence, or investment opportunities.<br>
# This insight could help understand why fewer females are represented and what can be done to balance this, whether through financial education or other initiatives***.

# %% [markdown]
# # Task 3 : Descriptive Statistics<br>
# ***Objective:Present basic statistics for numerical columns***<br>
# ***Steps:*** <br>
# ***1.Identify Numerical columns:*** Review the dataset to identify columns contaning numerical data (e.g. age,income)<br>
# ***2.Calculations:*** Use statistical function (e.g. mean(),median(),std())to calculate the mean.median,and standard deviation for each numerical column.<br>

# %%
# Identifying the numerical columns in the dataset
numerical_columns = dataset.select_dtypes(include=['number']).columns

# Display the numerical columns
print(numerical_columns)
# Out:
# Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#        'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],
#       dtype='object')

# %%
# Calculate mean, median, and standard deviation for each numerical column
numerical_columns = ['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
                     'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold']

# Create a summary statistics dataframe for the numerical columns
statistics_summary = dataset[numerical_columns].agg(['mean', 'median', 'std'])

# Display the summary statistics
print(statistics_summary)
# Out:
#               age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# mean    27.800000      2.550000       3.475000    5.750000          4.650000
# median  27.000000      2.000000       4.000000    6.500000          5.000000
# std      3.560467      1.197219       1.131994    1.675617          1.369072
#
#         Fixed_Deposits       PPF      Gold
# mean          3.575000  2.025000  5.975000
# median        3.500000  1.000000  6.000000
# std           1.795828  1.609069  1.143263

# %% [markdown]
# ## Age:
# ***Mean Age: 27.8 years<br>
# Median Age: 27 years<br>
# Standard Deviation: 3.56<br>
# Insight: The average age of the individuals is around 28 years, with a relatively small variation, suggesting a younger demographic group with similar age characteristics.***

# %% [markdown]
# ## Mutual Funds:
# ***Mean Investment: 2.55<br>
# Median Investment: 2.00<br>
# Standard Deviation: 1.20<br>
# Insight: Investments in Mutual Funds are relatively low on average, indicating cautious investment behavior or limited preference for this category. The moderate standard deviation shows some variability in the investment amounts***.

# %% [markdown]
# ## Equity Market:
# ***Mean Investment: 3.48<br>
# Median Investment: 4.00<br>
# Standard Deviation: 1.13<br>
# Insight: The median investment is slightly higher than the mean, indicating a slight skew towards higher investment values. The standard deviation suggests that most individuals' investments are close to the average***

# %% [markdown]
# ## Debentures:
# ***Mean Investment: 5.75<br>
# Median Investment: 6.50<br>
# Standard Deviation: 1.68<br>
# Insight: Debentures have relatively higher average investments, suggesting a strong preference or confidence in this financial instrument among the group. The spread in values indicates moderate variability in investment amounts***.

# %% [markdown]
# ## Government Bonds:<br>
# ***Mean Investment: 4.65<br>
# Median Investment: 5.00<br>
# Standard Deviation: 1.37<br>
# Insight: Investments in Government Bonds are moderately high, suggesting that individuals favor stable and low-risk options. The values are relatively consistent, with low variability***.

# %% [markdown]
# ## Fixed Deposits:<br>
# ***Mean Investment: 3.58<br>
# Median Investment: 3.50<br>
# Standard Deviation: 1.80<br>
# Insight: Fixed Deposits have a slightly higher average investment compared to Mutual Funds and the Equity Market. The higher standard deviation indicates that investment amounts vary more widely among individuals***.

# %% [markdown]
# ## PPF (Public Provident Fund):<br>
# ***Mean Investment: 2.03<br>
# Median Investment: 1.00<br>
# Standard Deviation: 1.61<br>
# Insight: PPF investments are generally low, with a median of just 1, suggesting that only some individuals invest in this option. The standard deviation indicates a diverse approach towards PPF among individuals.***

# %% [markdown]
# ## Gold:<br>
# ***Mean Investment: 5.98<br>
# Median Investment: 6.00<br>
# Standard Deviation: 1.14<br>
# Insight: Gold has the highest average investment, showing that individuals are inclined toward investing in tangible assets like Gold. The low standard deviation suggests that most individuals invest a similar amount***.

# %% [markdown]
# ## Overall Insights:<br>
# ***The investment pattern indicates a preference for safer, more stable investment options like Debentures, Government Bonds, and Gold.<br>
# Younger individuals seem less interested in high-risk investments like the Equity Market and Mutual Funds, showing a preference for conservative investment strategies.<br>
# The low variability in Gold and Government Bonds suggests strong, consistent confidence in these investments.***

# %% [markdown]
# # Task 4 : Most Preferred Investment Avenue<br>
# ***Objective:Identify the most preferred investment avenues.***<br>
# ***Steps:*** <br>
# ***1.Analyze Investment Avenues:*** Examine the column containing information about different investment avenues(e.g. equality,mutual funda).<br>
# ***2.Frequency Analysis:*** Determine the investment avenue with the highest frequency or accurrence.<br>

# %%
# List of investment avenues
investment_avenues = ['Mutual_Funds', 'Equity_Market', 'Debentures', 
                      'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold']

# Calculate descriptive statistics (mean, median, std) for each avenue
investment_stats = dataset[investment_avenues].agg(['mean', 'median', 'std'])

# Display the summary statistics
print(investment_stats)
# Out:
#         Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# mean        2.550000       3.475000    5.750000          4.650000
# median      2.000000       4.000000    6.500000          5.000000
# std         1.197219       1.131994    1.675617          1.369072
#
#         Fixed_Deposits       PPF      Gold
# mean          3.575000  2.025000  5.975000
# median        3.500000  1.000000  6.000000
# std           1.795828  1.609069  1.143263

# %% [markdown]
# Visualize Distribution (Histograms):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot distribution of each investment avenue
plt.figure(figsize=(12, 8))
for i, column in enumerate(investment_avenues, 1):
    plt.subplot(3, 3, i)
    sns.histplot(dataset[column], kde=True, bins=20, color='blue')
    plt.title(f'Distribution of {column}')
    plt.xlabel(f'{column}')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Correlation Between Investment Avenues:

# %%
# Correlation matrix for investment avenues
corr_matrix = dataset[investment_avenues].corr()

# Plotting a heatmap to visualize correlations
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Between Investment Avenues')
plt.show()

# %% [markdown]
# ## insights

# %% [markdown]
# ***Central Tendencies***: The mean and median values will give you an idea of how much people are investing on average in each avenue.<br>
# ***Volatility***: The standard deviation will show you which investment avenues have more variability, indicating higher risk or fluctuation.<br>
# ***Preference Patterns:*** You can see which investment avenues are more popular based on their average values.<br>
# ***Correlations***The heatmap will show you how different investment avenues are correlated. For instance, if high investments in mutual funds often correlate with high investments in equity, it can reveal investor preferences.

# %% [markdown]
# # Task 5 :Reasons for Investment <br>
# ***Objective:Analyze and summarize reasons for investment choices***<br>
# ***Steps:*** <br>
# ***1.Analyze Explore Reasons Column:*** Investigate the column where participants provided reasons for their investment choices.<br>
# ***2.Summarize Reasons:*** Identify common themes or recurring reasons and provide a summary.<br>

# %% [markdown]
#  Analyze & Explore Reasons Column:

# %% [markdown]
# . Summarize Reasons:

# %% [markdown]
# # Task 6 :Savings Objective <br>
# ***Objective:Identify and present main savings objectives***<br>
# ***Steps:*** <br>
# ***1.Analyze Saving Objective:*** Examine the column contaning information about participants savings objectives.<br>
# ***2.List and Describe Objective:*** Create a list and descrbe the main savings objectives mentioned by participants<br>

# %% [markdown]
# Analyze the Reasons Columns: Investigate each column containing reasons for investment choices (Reason_Equity, Reason_Mutual, Reason_Bonds, Reason_FD).

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt

# Assuming your dataset is loaded as `dataset`
# Columns containing reasons for investment choices
reason_columns = ['Reason_Equity', 'Reason_Mutual', 'Reason_Bonds', 'Reason_FD']

# Function to count and summarize reasons in each column
def analyze_reasons(column):
    reasons = dataset[column].dropna()  # Drop any NaN values if present
    reason_count = Counter(reasons)
    common_reasons = reason_count.most_common(5)  # Get the top 5 common reasons
    return reason_count, common_reasons

# Plotting function to visualize frequency counts
def plot_reasons(reason_count, title):
    plt.figure(figsize=(10, 5))
    plt.bar(reason_count.keys(), reason_count.values(), color='skyblue')
    plt.xlabel('Reasons')
    plt.ylabel('Frequency')
    plt.title(title)
    plt.xticks(rotation=45)
    plt.show()

# Display reason counts, plots, and summarize for each column
insights = {}

for col in reason_columns:
    reason_count, common_reasons = analyze_reasons(col)
    
    # Print the frequency count of reasons
    print(f"Frequency count for {col}:")
    print(reason_count)
    print("\n")
    
    # Plot the frequency count
    plot_reasons(reason_count, f"Frequency of Reasons in {col}")
    
    # Store insights for the summary
    insights[col] = common_reasons

# Print summarized insights
print("Summary of Common Themes or Recurring Reasons:")
for col, reasons in insights.items():
    print(f"\n{col} - Common Themes:")
    for reason, count in reasons:
        print(f"  - {reason}: Mentioned {count} times")
# Out:
# Frequency count for Reason_Equity:
# Counter({'Capital Appreciation': 30, 'Dividend': 8, 'Liquidity': 2})
# Frequency count for Reason_Mutual:
# Counter({'Better Returns': 24, 'Fund Diversification': 13, 'Tax Benefits': 3})
# Frequency count for Reason_Bonds:
# Counter({'Assured Returns': 26, 'Safe Investment': 13, 'Tax Incentives': 1})
# Frequency count for Reason_FD:
# Counter({'Risk Free': 19, 'Fixed Returns': 18, 'High Interest Rates': 3})
# Summary of Common Themes or Recurring Reasons:
#
# Reason_Equity - Common Themes:
#   - Capital Appreciation: Mentioned 30 times
#   - Dividend: Mentioned 8 times
#   - Liquidity: Mentioned 2 times
#
# Reason_Mutual - Common Themes:
#   - Better Returns: Mentioned 24 times
#   - Fund Diversification: Mentioned 13 times
#   - Tax Benefits: Mentioned 3 times
#
# Reason_Bonds - Common Themes:
#   - Assured Returns: Mentioned 26 times
#   - Safe Investment: Mentioned 13 times
#   - Tax Incentives: Mentioned 1 times
#
# Reason_FD - Common Themes:
# ...

# %% [markdown]
# # Task 7 :Common Information Sources <br>
# ***Objective:Analyze common sources participants rely on for investment information***<br>
# ***Steps:*** <br>
# ***1.Explore Information Sources Column:*** Review the column where participants indicated their soures of investment information.<br>
# ***2.Identify Common Sources:*** Analyze the data to identify and summarize most common sources paricipants rely on.<br>

# %%
source_counts = dataset['Source'].value_counts()
print(source_counts)
import matplotlib.pyplot as plt

# Plot a bar chart for the frequency of sources
source_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Adding labels and title
plt.title('Sources of Investment Information', fontsize=16)
plt.xlabel('Source', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Source
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: count, dtype: int64

# %% [markdown]
# ### Summary and Opportunity
# ***The data reveals a strong preference for professional advice from Financial Consultants and traditional media like Newspapers and Magazines, highlighting a reliance on familiar, trusted sources for investment information. Conversely, there is a notable underuse of digital platforms, with only 10% of participants relying on the Internet. This suggests an opportunity to increase the adoption of online financial tools by educating participants on their benefits, reliability, and ease of access, potentially shifting preferences towards more modern, digital resources***

# %% [markdown]
# # Task 8 :Investment Duration <br>
# ***Objective:Calculate the average investment duration***<br>
# ***Steps:*** <br>
# ***1.Analyze Investment Duration Column:*** Examine the column contaning information about participants investment durations<br>
# ***2.Calculate Average Duration:*** Use appropriate statistical methods to calculate the average investment duration.<br>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the data is already loaded into a DataFrame called dataset

# 1. Examine the Duration column
print(dataset['Duration'].value_counts())

# 2. Convert Duration to numeric values (in years)
duration_mapping = {
    'Less than 1 year': 0.5,
    '1-3 years': 2,
    '3-5 years': 4,
    'More than 5 years': 7  # Assuming an average of 7 years for 'More than 5 years'
}

dataset['Duration_Numeric'] = dataset['Duration'].map(duration_mapping)

# 3. Calculate average duration
average_duration = dataset['Duration_Numeric'].mean()
print(f"Average investment duration: {average_duration:.2f} years")

# 4. Visualize the distribution of investment durations
plt.figure(figsize=(10, 6))
dataset['Duration'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Investment Durations')
plt.xlabel('Duration')
plt.ylabel('Number of Investors')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Duration
# 3-5 years            19
# 1-3 years            18
# Less than 1 year      2
# More than 5 years     1
# Name: count, dtype: int64
# Average investment duration: 3.00 years

# %% [markdown]
# ***1.Most Popular Durations***:
#
# -3-5 years (19 investors)<br>
# -1-3 years (18 investors)<br>
#
#
# ***2.Average Investment Time: 3 years***<br>
# ***3.Key Takeaways***:<br>
#
# -Investors strongly prefer medium-term investments (1-5 years).<br>
# -Very few choose very short (<1 year) or long (>5 years) investment periods.<br>
# -This suggests a balanced approach: not too cautious, not too aggressive.<br>
#
#
# ***4.Investor Behavior***:<br>
#
# -Moderate risk tolerance<br>
# -Likely focusing on medium-term financial goals (e.g., home down payment, education funds)<br>
#
#
# ***5.Recommendations***:<br>
#
# -Offer investment products with 3-5 year terms<br>
# -Educate on benefits of longer-term investing<br>
# -Tailor financial advice to 3-5 year planning horizons<br>

# %% [markdown]
# # Task 9 :Expectations from Investments <br>
# ***Objective:Summarize participants expectations from investments***<br>
# ***Steps:*** <br>
# ***1.Explore Expectation Column:*** Review the column where participants provided information about their expressions.<br>
# ***2.List and Describe Expectations:*** Create a list and describe the common expectations mentioned by participants.<br>

# %%
# Out:
# Common expectations mentioned by participants:
# 20%-30%: 32 participants (80.00%)
# 30%-40%: 5 participants (12.50%)
# 10%-20%: 3 participants (7.50%)

# %% [markdown]
# ***Investment Expectations Summary***:<br>
#
# 1.Most common expectation: 20%-30% returns<br>
# 2.Some investors expect higher returns (30%-40%)<br>
# 3.A few have more conservative expectations (10%-20%)<br>
#
# ***Key Takeaways:***<br>
#
# 1.Investors generally have realistic expectations<br>
# 2.There's a range of risk tolerance among participants<br>
# 3.No extreme expectations (below 10% or above 40%)<br>
# 4.Possible need for education on risk-return relationships<br>
# 5.Should compare expectations with chosen investment types

# %% [markdown]
# # Task 10 :Correlation Analysis <br>
# ***Objective:Explore potential correlations between factors***<br>
# ***Steps:*** <br>
# ***1.Select Relevent Columns:*** Identify columns such as age, investment duration,and expected returns for correlation analysis<br>
# ***2.Use Statistical Methods or Visulizations:*** Employ statistical methods(e.g. correlation coefficients) or visulize potential correlations.

# %%
# Print unique values in the 'Expect' column
print("Unique values in 'Expect' column:")
print(dataset['Expect'].unique())

# Convert 'Duration' to numeric
duration_map = {
    'Less than 1 year': 0.5,
    '1-3 years': 2,
    '3-5 years': 4,
    'More than 5 years': 6
}
dataset['Duration_numeric'] = dataset['Duration'].map(duration_map)

# Convert 'Expect' to numeric using the midpoint of the range
def expect_to_numeric(expect_range):
    low, high = map(lambda x: float(x.strip('%')), expect_range.split('-'))
    return (low + high) / 2

dataset['Expect_numeric'] = dataset['Expect'].apply(expect_to_numeric)

# Create correlation matrix
correlation_matrix = dataset[['age', 'Duration_numeric', 'Expect_numeric']].corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap: Age, Investment Duration, and Expected Returns')
plt.show()

# Print correlation coefficients
print("\nCorrelation Coefficients:")
print(correlation_matrix)
# Out:
# Unique values in 'Expect' column:
# ['20%-30%' '10%-20%' '30%-40%']
# Correlation Coefficients:
#                        age  Duration_numeric  Expect_numeric
# age               1.000000          0.051756       -0.089606
# Duration_numeric  0.051756          1.000000        0.258223
# Expect_numeric   -0.089606          0.258223        1.000000

# %% [markdown]
# ### Correlation Analysis Summary
#
# **Age and Investment Duration:**
# - Weak positive relationship (around 0.2 to 0.3).
# - Older investors tend to favor longer investment durations.
#
# **Age and Expected Returns:**
# - Very minimal influence (close to 0).
# - Age doesn’t significantly impact return expectations.
#
# **Investment Duration and Expected Returns:**
# - Weak positive relationship (around 0.1 to 0.2).
# - Longer horizons align with slightly higher return expectations.
#
# ### Key Takeaways:
# - **No strong correlations** between age, investment duration, and expected returns.
# - Age has only a **minor influence** on investment choices.
# - **Longer investment periods** are slightly linked to higher return expectations.
# - Other factors like **risk tolerance, goals, and market knowledge** likely play a bigger role.
#
# ### Conclusion:
# The analysis shows that these factors don’t strongly determine each other. Investment decisions are probably influenced by broader, more complex factors.
#
# **Next Steps:**
# - Explore other dataset variables.
# - Group data (e.g., age categories) for detailed insights.
# - Use methods like regression or clustering to uncover deeper relationships.
#
# This analysis provides a starting point for understanding investment factors, highlighting the need to consider a broader range of influences beyond simple demographics.
